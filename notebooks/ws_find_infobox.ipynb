# %%
import os
import sys

project_path = os.path.abspath("..")

sys.path.append(project_path)

# %%
from urllib.parse import urlparse

from bs4 import BeautifulSoup as bs

from src.scrap_hrefs import get_section_hrefs
from src.scrap_infobox import extract_unit_data
from src.utils import fetch_page_content

# %% [markdown]
# ## Implementation

# %%
def get_units_urls(url) -> list:
    
    units_url = url + "wiki/Unit_(Age_of_Empires_III)"
    unit_list_html = fetch_page_content(units_url)
    href_soup = bs(unit_list_html, "html.parser")

    content = href_soup.find('div', class_='mw-parser-output')
    h2s = content.find_all('h2', recursive=False)
    sections = [h2.find('span', class_='mw-headline', recursive=False).text for h2 in h2s]
    # section_unit_hrefs = {section: get_units_hrefs(section, content) for section in sections}
    units_urls = [
        url + href
        for section in sections
        for href in get_section_hrefs(section, content).values()
    ]

    return units_urls

# %%
url = "https://ageofempires.fandom.com/"

units_urls = get_units_urls(url)
units_urls
# Out:
# ['https://ageofempires.fandom.com//wiki/Tiger#Axehilt_the_Tame_Tiger',
#  'https://ageofempires.fandom.com//wiki/Wolf#Buck_the_Tame_Wolf',
#  'https://ageofempires.fandom.com//wiki/Carib_Blowgunner',
#  'https://ageofempires.fandom.com//wiki/Coyote#Fang_the_Tame_Coyote',
#  'https://ageofempires.fandom.com//wiki/Disciple',
#  'https://ageofempires.fandom.com//wiki/Eagle_Scout_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Envoy_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Hot_Air_Balloon',
#  'https://ageofempires.fandom.com//wiki/Jaguar#Janey_the_Pet_Jaguar',
#  'https://ageofempires.fandom.com//wiki/Nootka_War_Chief',
#  'https://ageofempires.fandom.com//wiki/Dog#Peruvian_Dog',
#  'https://ageofempires.fandom.com//wiki/White_Tiger_(Age_of_Empires_III)#Wagner_the_Pet_White_Tiger',
#  'https://ageofempires.fandom.com//wiki/Dog#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Architect',
#  'https://ageofempires.fandom.com//wiki/Barbary_Warrior',
#  'https://ageofempires.fandom.com//wiki/Bashibozuk',
#  'https://ageofempires.fandom.com//wiki/Californio',
#  'https://ageofempires.fandom.com//wiki/Cougar#Buttercup',
#  'https://ageofempires.fandom.com//wiki/Coureur_des_Bois',
#  'https://ageofempires.fandom.com//wiki/Cuerudo',
#  'https://ageofempires.fandom.com//wiki/Chasqui',
#  'https://ageofempires.fandom.com//wiki/Eclaireur',
#  'https://ageofempires.fandom.com//wiki/Envoy_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Filibuster',
#  'https://ageofempires.fandom.com//wiki/Hindu_Villager',
#  'https://ageofempires.fandom.com//wiki/Javanese_Spearman',
#  'https://ageofempires.fandom.com//wiki/Skirmisher_(Age_of_Empires_III)#Karelian_Jaeger',
#  'https://ageofempires.fandom.com//wiki/Merchant_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Militiaman',
#  'https://ageofempires.fandom.com//wiki/Native_Scout',
#  'https://ageofempires.fandom.com//wiki/Revolutionary',
#  'https://ageofempires.fandom.com//wiki/Settler',
#  'https://ageofempires.fandom.com//wiki/Villager_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/State_Militia',
#  'https://ageofempires.fandom.com//wiki/Y%C3%B6r%C3%BCk',
#  'https://ageofempires.fandom.com//wiki/Settler_Wagon',
#  'https://ageofempires.fandom.com//wiki/Cow#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Goat#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Llama#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Sheep#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Atakebune_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Bandit_Catamaran',
#  'https://ageofempires.fandom.com//wiki/Battle_Canoe',
#  'https://ageofempires.fandom.com//wiki/Battleship',
#  'https://ageofempires.fandom.com//wiki/Cannon_Boat',
#  'https://ageofempires.fandom.com//wiki/Canoe_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Caravel_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Chincha_Raft',
#  'https://ageofempires.fandom.com//wiki/Fire_Junk',
#  'https://ageofempires.fandom.com//wiki/Fishing_Boat_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Fishing_Canoe',
#  'https://ageofempires.fandom.com//wiki/Fire_Ship_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Fluyt',
#  'https://ageofempires.fandom.com//wiki/Frigate',
#  'https://ageofempires.fandom.com//wiki/Fuchuan',
#  'https://ageofempires.fandom.com//wiki/Fune',
#  'https://ageofempires.fandom.com//wiki/Galleass_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Galleon_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Galley_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Ironclad_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Marathan_Catamaran',
#  'https://ageofempires.fandom.com//wiki/Monitor',
#  'https://ageofempires.fandom.com//wiki/Order_Galley',
#  'https://ageofempires.fandom.com//wiki/Privateer',
#  'https://ageofempires.fandom.com//wiki/Sloop',
#  'https://ageofempires.fandom.com//wiki/Steamer',
#  'https://ageofempires.fandom.com//wiki/Tekkousen',
#  'https://ageofempires.fandom.com//wiki/Tlaloc_Canoe',
#  'https://ageofempires.fandom.com//wiki/War_Canoe',
#  'https://ageofempires.fandom.com//wiki/War_Dhow',
#  'https://ageofempires.fandom.com//wiki/War_Junk',
#  'https://ageofempires.fandom.com//wiki/Wokou_Junk',
#  'https://ageofempires.fandom.com//wiki/Xebec',
#  'https://ageofempires.fandom.com//wiki/Akan_Ankobia',
#  'https://ageofempires.fandom.com//wiki/Apache_Cavalry',
#  'https://ageofempires.fandom.com//wiki/Aztec_Eagle_Warrior',
#  'https://ageofempires.fandom.com//wiki/Aztec_Jaguar_Warrior',
#  'https://ageofempires.fandom.com//wiki/Berber_Camel_Rider',
#  'https://ageofempires.fandom.com//wiki/Berber_Nomad',
#  'https://ageofempires.fandom.com//wiki/Berber_Salt_Camel',
#  'https://ageofempires.fandom.com//wiki/Black_Brunswicker',
#  'https://ageofempires.fandom.com//wiki/Boyar_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Captured_Mortar',
#  'https://ageofempires.fandom.com//wiki/Carib_Blowgunner',
#  'https://ageofempires.fandom.com//wiki/Chakram_Thrower_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Chasqui',
#  'https://ageofempires.fandom.com//wiki/Cherokee_Rifleman',
#  'https://ageofempires.fandom.com//wiki/Chevauleger',
#  'https://ageofempires.fandom.com//wiki/Cheyenne_Rider',
#  'https://ageofempires.fandom.com//wiki/Comanche_Horse_Archer',
#  'https://ageofempires.fandom.com//wiki/Conquistador_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Cree_Tracker',
#  'https://ageofempires.fandom.com//wiki/Cree_Coureur_des_Bois',
#  'https://ageofempires.fandom.com//wiki/Drummer',
#  'https://ageofempires.fandom.com//wiki/Evzone',
#  'https://ageofempires.fandom.com//wiki/Haudenosaunee_Mantlet',
#  'https://ageofempires.fandom.com//wiki/Haudenosaunee_Tomahawk',
#  'https://ageofempires.fandom.com//wiki/Healer_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Huron_Mantlet',
#  'https://ageofempires.fandom.com//wiki/Klamath_Rifleman',
#  'https://ageofempires.fandom.com//wiki/Line_Infantry',
#  'https://ageofempires.fandom.com//wiki/Lipka_Tatar',
#  'https://ageofempires.fandom.com//wiki/Mapuche_Ironwood_Clubman',
#  'https://ageofempires.fandom.com//wiki/Mapuche_Bolas_Rider',
#  'https://ageofempires.fandom.com//wiki/Maya_Holcan_Javelineer',
#  'https://ageofempires.fandom.com//wiki/Mountain_Trooper',
#  'https://ageofempires.fandom.com//wiki/Mounted_Infantry',
#  'https://ageofempires.fandom.com//wiki/Navajo_Rifleman',
#  'https://ageofempires.fandom.com//wiki/Nootka_Clubman',
#  'https://ageofempires.fandom.com//wiki/Northern_Musketeer',
#  'https://ageofempires.fandom.com//wiki/Qizilbash',
#  'https://ageofempires.fandom.com//wiki/Quechua_Bolas_Warrior',
#  'https://ageofempires.fandom.com//wiki/Quechua_Huaminca',
#  'https://ageofempires.fandom.com//wiki/Rattan_Shield',
#  'https://ageofempires.fandom.com//wiki/Royal_Arquebusier',
#  'https://ageofempires.fandom.com//wiki/Royal_Dragoon',
#  'https://ageofempires.fandom.com//wiki/Royal_Huntsman',
#  'https://ageofempires.fandom.com//wiki/Royal_Musketeer',
#  'https://ageofempires.fandom.com//wiki/Saxon_Cuirassier',
#  'https://ageofempires.fandom.com//wiki/Seminole_Sharktooth_Bowman',
#  'https://ageofempires.fandom.com//wiki/Shock_Rider',
#  'https://ageofempires.fandom.com//wiki/Sohei_Naginata',
#  'https://ageofempires.fandom.com//wiki/Somali_Darood_Militia',
#  'https://ageofempires.fandom.com//wiki/Somali_Issa_Warrior',
#  'https://ageofempires.fandom.com//wiki/Sudanese_Dervish',
#  'https://ageofempires.fandom.com//wiki/Tatar_Archer',
#  'https://ageofempires.fandom.com//wiki/Tengri_Wolf',
#  'https://ageofempires.fandom.com//wiki/Tiger_Claw',
#  'https://ageofempires.fandom.com//wiki/Totenkopf_Hussar',
#  'https://ageofempires.fandom.com//wiki/Trabant',
#  'https://ageofempires.fandom.com//wiki/Tupi_Blackwood_Archer',
#  'https://ageofempires.fandom.com//wiki/Winged_Hussar_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/War_Elephant_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Yoruba_Oyo_Legionary',
#  'https://ageofempires.fandom.com//wiki/Yoruba_Eso_Rider',
#  'https://ageofempires.fandom.com//wiki/Zapotec_Lightning_Warrior',
#  'https://ageofempires.fandom.com//wiki/Imam_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Missionary_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Muhbir',
#  'https://ageofempires.fandom.com//wiki/Padre',
#  'https://ageofempires.fandom.com//wiki/Priest_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Spy_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Surgeon',
#  'https://ageofempires.fandom.com//wiki/Papal_Guard',
#  'https://ageofempires.fandom.com//wiki/Papal_Lancer',
#  'https://ageofempires.fandom.com//wiki/Papal_Zouave',
#  'https://ageofempires.fandom.com//wiki/Priest_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Schiavone',
#  'https://ageofempires.fandom.com//wiki/Spy_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Ashigaru_Musketeer',
#  'https://ageofempires.fandom.com//wiki/Azap',
#  'https://ageofempires.fandom.com//wiki/Bersagliere',
#  'https://ageofempires.fandom.com//wiki/Carolean',
#  'https://ageofempires.fandom.com//wiki/Cassador',
#  'https://ageofempires.fandom.com//wiki/Corsair_Marksman',
#  'https://ageofempires.fandom.com//wiki/Crossbowman_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Salteador#Cruzob_Avenger',
#  'https://ageofempires.fandom.com//wiki/Cruzob_Infantry',
#  'https://ageofempires.fandom.com//wiki/Doppelsoldner',
#  'https://ageofempires.fandom.com//wiki/Gurkha',
#  'https://ageofempires.fandom.com//wiki/Halberdier_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Insurgente',
#  'https://ageofempires.fandom.com//wiki/Janissary_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Landwehr',
#  'https://ageofempires.fandom.com//wiki/Longbowman_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Musketeer',
#  'https://ageofempires.fandom.com//wiki/Nizam_Fusilier',
#  'https://ageofempires.fandom.com//wiki/Ordinance_Rifleman',
#  'https://ageofempires.fandom.com//wiki/Pavisier',
#  'https://ageofempires.fandom.com//wiki/Pikeman_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Poruchik',
#  'https://ageofempires.fandom.com//wiki/Rajput',
#  'https://ageofempires.fandom.com//wiki/Ranger',
#  'https://ageofempires.fandom.com//wiki/Regular',
#  'https://ageofempires.fandom.com//wiki/Rekrut',
#  'https://ageofempires.fandom.com//wiki/Rodelero',
#  'https://ageofempires.fandom.com//wiki/Salteador',
#  'https://ageofempires.fandom.com//wiki/Samurai_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Sepoy',
#  'https://ageofempires.fandom.com//wiki/Sharpshooter',
#  'https://ageofempires.fandom.com//wiki/Skirmisher_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Soldado',
#  'https://ageofempires.fandom.com//wiki/State_Militia',
#  'https://ageofempires.fandom.com//wiki/Strelet',
#  'https://ageofempires.fandom.com//wiki/Yumi_Archer',
#  'https://ageofempires.fandom.com//wiki/Hospitaller',
#  'https://ageofempires.fandom.com//wiki/Sentinel_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Carbine_Cavalry',
#  'https://ageofempires.fandom.com//wiki/Cavalry_Archer_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Chinaco',
#  'https://ageofempires.fandom.com//wiki/Cossack',
#  'https://ageofempires.fandom.com//wiki/Cuirassier',
#  'https://ageofempires.fandom.com//wiki/Deli',
#  'https://ageofempires.fandom.com//wiki/Dragoon',
#  'https://ageofempires.fandom.com//wiki/Hakkapelit',
#  'https://ageofempires.fandom.com//wiki/Hussar_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Lancer_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Mounted_Granadero',
#  'https://ageofempires.fandom.com//wiki/Naginata_Rider',
#  'https://ageofempires.fandom.com//wiki/Oprichnik',
#  'https://ageofempires.fandom.com//wiki/Ruyter',
#  'https://ageofempires.fandom.com//wiki/Uhlan',
#  'https://ageofempires.fandom.com//wiki/War_Wagon_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Yabusame',
#  'https://ageofempires.fandom.com//wiki/Abus_Gunner',
#  'https://ageofempires.fandom.com//wiki/Culverin_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Falconet',
#  'https://ageofempires.fandom.com//wiki/Fire_Thrower',
#  'https://ageofempires.fandom.com//wiki/Gatling_Gun',
#  'https://ageofempires.fandom.com//wiki/Grenadier_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Hoop_Thrower',
#  'https://ageofempires.fandom.com//wiki/Horse_Artillery',
#  'https://ageofempires.fandom.com//wiki/Humbaraci',
#  'https://ageofempires.fandom.com//wiki/Leather_Cannon',
#  'https://ageofempires.fandom.com//wiki/Mortar',
#  'https://ageofempires.fandom.com//wiki/Organ_Gun_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Petard_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Quaker_Gun',
#  'https://ageofempires.fandom.com//wiki/Rocket',
#  'https://ageofempires.fandom.com//wiki/Great_Bombard_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Heavy_Cannon',
#  'https://ageofempires.fandom.com//wiki/Papal_Bombard',
#  'https://ageofempires.fandom.com//wiki/Rocket',
#  'https://ageofempires.fandom.com//wiki/Hussar_(Age_of_Empires_III)#Magyar_Hussar',
#  'https://ageofempires.fandom.com//wiki/Armored_Pistoleer',
#  'https://ageofempires.fandom.com//wiki/Arsonist',
#  'https://ageofempires.fandom.com//wiki/Askari',
#  'https://ageofempires.fandom.com//wiki/Barbary_Corsair',
#  'https://ageofempires.fandom.com//wiki/Bandido',
#  'https://ageofempires.fandom.com//wiki/Black_Rider_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Bosniak',
#  'https://ageofempires.fandom.com//wiki/Cannoneer',
#  'https://ageofempires.fandom.com//wiki/Comanchero',
#  'https://ageofempires.fandom.com//wiki/Cossack_Daredevil',
#  'https://ageofempires.fandom.com//wiki/Cowboy_(Saloon)',
#  'https://ageofempires.fandom.com//wiki/Crabat',
#  'https://ageofempires.fandom.com//wiki/Cuatrero',
#  'https://ageofempires.fandom.com//wiki/Dacoit',
#  'https://ageofempires.fandom.com//wiki/Dahomey_Amazon',
#  'https://ageofempires.fandom.com//wiki/Desperado',
#  'https://ageofempires.fandom.com//wiki/Elmetto',
#  'https://ageofempires.fandom.com//wiki/Fusilier',
#  'https://ageofempires.fandom.com//wiki/Gatling_Camel',
#  'https://ageofempires.fandom.com//wiki/Giant_Grenadier',
#  'https://ageofempires.fandom.com//wiki/Gunslinger',
#  'https://ageofempires.fandom.com//wiki/Hackapell',
#  'https://ageofempires.fandom.com//wiki/Hajduk',
#  'https://ageofempires.fandom.com//wiki/Harquebusier',
#  'https://ageofempires.fandom.com//wiki/Highwayman',
#  'https://ageofempires.fandom.com//wiki/Highlander',
#  'https://ageofempires.fandom.com//wiki/Inquisitor',
#  'https://ageofempires.fandom.com//wiki/Irish_Brigadier',
#  'https://ageofempires.fandom.com//wiki/Iron_Troop',
#  'https://ageofempires.fandom.com//wiki/Jaeger',
#  'https://ageofempires.fandom.com//wiki/Jat_Lancer',
#  'https://ageofempires.fandom.com//wiki/Kanuri_Guard',
#  'https://ageofempires.fandom.com//wiki/Landsknecht_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Li%27l_Bombard',
#  'https://ageofempires.fandom.com//wiki/Maigadi',
#  'https://ageofempires.fandom.com//wiki/Mameluke_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Manchu',
#  'https://ageofempires.fandom.com//wiki/Mounted_Rifleman',
#  'https://ageofempires.fandom.com//wiki/Napoleon_Gun',
#  'https://ageofempires.fandom.com//wiki/Ninja_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Owlhoot',
#  'https://ageofempires.fandom.com//wiki/Pandour',
#  'https://ageofempires.fandom.com//wiki/Pirate_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Pistolero',
#  'https://ageofempires.fandom.com//wiki/Renegado',
#  'https://ageofempires.fandom.com//wiki/Ronin',
#  'https://ageofempires.fandom.com//wiki/Royal_Horseman',
#  'https://ageofempires.fandom.com//wiki/Sennar_Horseman',
#  'https://ageofempires.fandom.com//wiki/Stradiot',
#  'https://ageofempires.fandom.com//wiki/Swiss_Pikeman',
#  'https://ageofempires.fandom.com//wiki/Thuggee',
#  'https://ageofempires.fandom.com//wiki/Wokou_Horseman',
#  'https://ageofempires.fandom.com//wiki/Wokou_Monk',
#  'https://ageofempires.fandom.com//wiki/Wokou_Pirate',
#  'https://ageofempires.fandom.com//wiki/Wokou_Ronin',
#  'https://ageofempires.fandom.com//wiki/Yojimbo',
#  'https://ageofempires.fandom.com//wiki/Zenata_Rider',
#  'https://ageofempires.fandom.com//wiki/Zouave',
#  'https://ageofempires.fandom.com//wiki/Aenna',
#  'https://ageofempires.fandom.com//wiki/Cetan_Bow',
#  'https://ageofempires.fandom.com//wiki/Chimu_Runner',
#  'https://ageofempires.fandom.com//wiki/Club_Warrior',
#  'https://ageofempires.fandom.com//wiki/Coyote_Runner',
#  'https://ageofempires.fandom.com//wiki/Forest_Prowler',
#  'https://ageofempires.fandom.com//wiki/Jungle_Bowman',
#  'https://ageofempires.fandom.com//wiki/Otontin_Slinger',
#  'https://ageofempires.fandom.com//wiki/Plumed_Spearman',
#  'https://ageofempires.fandom.com//wiki/Puma_Spearman',
#  'https://ageofempires.fandom.com//wiki/Tomahawk',
#  'https://ageofempires.fandom.com//wiki/Wakina_Rifle',
#  'https://ageofempires.fandom.com//wiki/Axe_Rider',
#  'https://ageofempires.fandom.com//wiki/Bow_Rider',
#  'https://ageofempires.fandom.com//wiki/Kanya_Horseman',
#  'https://ageofempires.fandom.com//wiki/Musket_Rider',
#  'https://ageofempires.fandom.com//wiki/Rifle_Rider',
#  'https://ageofempires.fandom.com//wiki/Tashunke_Prowler',
#  'https://ageofempires.fandom.com//wiki/Light_Cannon',
#  'https://ageofempires.fandom.com//wiki/Mantlet',
#  'https://ageofempires.fandom.com//wiki/Ram_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Arrow_Knight',
#  'https://ageofempires.fandom.com//wiki/Eagle_Runner_Knight',
#  'https://ageofempires.fandom.com//wiki/Jaguar_Prowl_Knight',
#  'https://ageofempires.fandom.com//wiki/Bolas_Warrior',
#  'https://ageofempires.fandom.com//wiki/Huaraca',
#  'https://ageofempires.fandom.com//wiki/Maceman_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Healer_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Priestess_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Maceman_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Skull_Knight',
#  'https://ageofempires.fandom.com//wiki/Tokala_Soldier',
#  'https://ageofempires.fandom.com//wiki/Warrior',
#  'https://ageofempires.fandom.com//wiki/Warrior_Priest_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Goat#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Water_Buffalo#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Sacred_Cow',
#  'https://ageofempires.fandom.com//wiki/Forbidden_Army',
#  'https://ageofempires.fandom.com//wiki/Imperial_Army',
#  'https://ageofempires.fandom.com//wiki/Ming_Army',
#  'https://ageofempires.fandom.com//wiki/Old_Han_Army',
#  'https://ageofempires.fandom.com//wiki/Standard_Army',
#  'https://ageofempires.fandom.com//wiki/Territorial_Army',
#  'https://ageofempires.fandom.com//wiki/Howdah_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Mahout_Lancer',
#  'https://ageofempires.fandom.com//wiki/Sowar',
#  'https://ageofempires.fandom.com//wiki/Zamburak',
#  'https://ageofempires.fandom.com//wiki/Black_Flag_Army',
#  'https://ageofempires.fandom.com//wiki/Flail_Elephant',
#  'https://ageofempires.fandom.com//wiki/Flamethrower_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Flaming_Arrow',
#  'https://ageofempires.fandom.com//wiki/Hand_Mortar',
#  'https://ageofempires.fandom.com//wiki/Mongolian_Army',
#  'https://ageofempires.fandom.com//wiki/Morutaru',
#  'https://ageofempires.fandom.com//wiki/Siege_Elephant_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Flying_Crow',
#  'https://ageofempires.fandom.com//wiki/Daimyo',
#  'https://ageofempires.fandom.com//wiki/Tokugawa_Ieyasu#In-game_unit_(skirmish)',
#  'https://ageofempires.fandom.com//wiki/Flail_Elephant#Mansabdar_Flail_Elephant',
#  'https://ageofempires.fandom.com//wiki/Gurkha#Mansabdar_Gurkha',
#  'https://ageofempires.fandom.com//wiki/Howdah_(Age_of_Empires_III)#Mansabdar_Howdah',
#  'https://ageofempires.fandom.com//wiki/Mahout_Lancer#Mansabdar_Mahout',
#  'https://ageofempires.fandom.com//wiki/Rajput#Mansabdar_Rajput',
#  'https://ageofempires.fandom.com//wiki/Sepoy#Mansabdar_Sepoy',
#  'https://ageofempires.fandom.com//wiki/Sowar#Mansabdar_Sowar',
#  'https://ageofempires.fandom.com//wiki/Urumi_Swordsman_(Age_of_Empires_III)#Mansabdar_Urumi',
#  'https://ageofempires.fandom.com//wiki/Zamburak#Mansabdar_Zamburak',
#  'https://ageofempires.fandom.com//wiki/Siege_Elephant_(Age_of_Empires_III)#Mansabdar_Siege_Elephant',
#  'https://ageofempires.fandom.com//wiki/Fulani_Archer',
#  'https://ageofempires.fandom.com//wiki/Gascenya',
#  'https://ageofempires.fandom.com//wiki/Javelin_Rider',
#  'https://ageofempires.fandom.com//wiki/Lifidi_Knight',
#  'https://ageofempires.fandom.com//wiki/Neftenya',
#  'https://ageofempires.fandom.com//wiki/Oromo_Warrior',
#  'https://ageofempires.fandom.com//wiki/Raider_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Shotel_Warrior_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Bank_Wagon',
#  'https://ageofempires.fandom.com//wiki/Covered_Wagon',
#  'https://ageofempires.fandom.com//wiki/Estate_Wagon',
#  'https://ageofempires.fandom.com//wiki/Mill_Wagon',
#  'https://ageofempires.fandom.com//wiki/Outpost_Wagon',
#  'https://ageofempires.fandom.com//wiki/Trading_Post_Wagon',
#  'https://ageofempires.fandom.com//wiki/Ronin',
#  'https://ageofempires.fandom.com//wiki/Yamabushi',
#  'https://ageofempires.fandom.com//wiki/Ninja_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Shinobi_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Morgan%27s_Flagship',
#  'https://ageofempires.fandom.com//wiki/Lizzie%27s_Flagship',
#  'https://ageofempires.fandom.com//wiki/Fire_Ship_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Barbary_Corsair#Buccaneer_Captain',
#  'https://ageofempires.fandom.com//wiki/Aztec_Chief',
#  'https://ageofempires.fandom.com//wiki/Dinghy',
#  'https://ageofempires.fandom.com//wiki/Native_Boy',
#  'https://ageofempires.fandom.com//wiki/Treasure_Ship',
#  'https://ageofempires.fandom.com//wiki/White_Jaguar',
#  'https://ageofempires.fandom.com//wiki/Boneguard_Swordsman',
#  'https://ageofempires.fandom.com//wiki/Boneguard_Musketeer',
#  'https://ageofempires.fandom.com//wiki/Cherokee_Archer',
#  'https://ageofempires.fandom.com//wiki/Cherokee_Horse_Archer',
#  'https://ageofempires.fandom.com//wiki/Native_American_Chief',
#  'https://ageofempires.fandom.com//wiki/Musketeer#Outlaw_Musketeer',
#  'https://ageofempires.fandom.com//wiki/White_Buffalo',
#  'https://ageofempires.fandom.com//wiki/Great_Plains_Chief',
#  'https://ageofempires.fandom.com//wiki/Greta',
#  'https://ageofempires.fandom.com//wiki/Horse#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Miner',
#  'https://ageofempires.fandom.com//wiki/Li%27l_Bombard#Great_Cannon',
#  'https://ageofempires.fandom.com//wiki/Railroad_Worker',
#  'https://ageofempires.fandom.com//wiki/White_Wolf',
#  'https://ageofempires.fandom.com//wiki/Cougar#Fierce_Cougar',
#  'https://ageofempires.fandom.com//wiki/Black_Powder_Wagon',
#  'https://ageofempires.fandom.com//wiki/Flat-bottomed_Boat',
#  'https://ageofempires.fandom.com//wiki/Morgan%27s_Flagship',
#  'https://ageofempires.fandom.com//wiki/Lizzie%27s_Flagship',
#  'https://ageofempires.fandom.com//wiki/Fire_Ship_(Age_of_Empires_III)',
#  'https://ageofempires.fandom.com//wiki/Barbary_Corsair#Buccaneer_Captain',
#  'https://ageofempires.fandom.com//wiki/Aztec_Chief',
#  'https://ageofempires.fandom.com//wiki/Dinghy',
#  'https://ageofempires.fandom.com//wiki/Native_Boy',
#  'https://ageofempires.fandom.com//wiki/Treasure_Ship',
#  'https://ageofempires.fandom.com//wiki/White_Jaguar',
#  'https://ageofempires.fandom.com//wiki/Boneguard_Swordsman',
#  'https://ageofempires.fandom.com//wiki/Boneguard_Musketeer',
#  'https://ageofempires.fandom.com//wiki/Cherokee_Archer',
#  'https://ageofempires.fandom.com//wiki/Cherokee_Horse_Archer',
#  'https://ageofempires.fandom.com//wiki/Native_American_Chief',
#  'https://ageofempires.fandom.com//wiki/Musketeer#Outlaw_Musketeer',
#  'https://ageofempires.fandom.com//wiki/White_Buffalo',
#  'https://ageofempires.fandom.com//wiki/Great_Plains_Chief',
#  'https://ageofempires.fandom.com//wiki/Greta',
#  'https://ageofempires.fandom.com//wiki/Horse#Age_of_Empires_III',
#  'https://ageofempires.fandom.com//wiki/Miner',
#  'https://ageofempires.fandom.com//wiki/Li%27l_Bombard#Great_Cannon',
#  'https://ageofempires.fandom.com//wiki/Railroad_Worker',
#  'https://ageofempires.fandom.com//wiki/White_Wolf',
#  'https://ageofempires.fandom.com//wiki/Cougar#Fierce_Cougar',
#  'https://ageofempires.fandom.com//wiki/Black_Powder_Wagon',
#  'https://ageofempires.fandom.com//wiki/Flat-bottomed_Boat']

# %%
def get_infoboxes(url, target_game):

    try:

        unit_html = fetch_page_content(url)
        unit_soup = bs(unit_html, "html.parser")
        infoboxes = unit_soup.find_all("aside", class_="portable-infobox")

        valid_infoboxes = []
        for infobox in infoboxes:
            
            game_div = infobox.find("div", class_="pi-data-value")
            
            if not game_div:
                continue

            game = game_div.text.strip()

            if target_game in game:
                valid_infoboxes.append(infobox)

        return valid_infoboxes

    except Exception as e:
        raise Exception(f"Error: {e}")

# %%
url = "https://ageofempires.fandom.com/wiki/Gatling_Gun"
infoboxes = get_infoboxes(url, "Age of Empires III")
unit_data = extract_unit_data(infoboxes[0])
unit_data
# Out:
# Error extracting data form block 'Bombard attack' in 'Gatling Gun' infobox: Information for label 'Damage' could not be extracted in dict format.
# Present values: ['30 (6)']
# {'name': 'Gatling Gun',
#  'Information': {'Introduced in': 'Age of Empires III: The WarChiefs',
#   'Type': ['Artillery'],
#   'Civilization(s)': ['Revolutionary',
#    'United States',
#    'United States (revolutionary)'],
#   'Age': ['Fortress Age (United States)', 'Revolution (revolutionary)']},
#  'Training': {'Trained at': ['Artillery Foundry',
#    'Fort',
#    'Steamer (United States)',
#    'American Citadel'],
#   'Cost': {'Wood': '100', 'Coin': '250', 'Population': '4'},
#   'Train time': {'seconds': '38'}},
#  'Statistics': {'Hit points': '150',
#   'Resistance': {'Ranged': '75%'},
#   'Speed': '4.0',
#   'Line of Sight': '26',
#   'Train XP': '35',
#   'Kill XP': '35'}}

# %%
data = []
TARGET_GAME = "Age of Empires III"
for url in units_urls:
    infoboxes = get_infoboxes(url, TARGET_GAME)
    for infobox in infoboxes:
        try:
            unit_data = extract_unit_data(infobox)
            data.append(unit_data)
        except Exception as e:
            print(f"Extraction error for {url}: {e}")

print(f"Extracted data for {len(data)} units")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 TARGET_GAME = "Age of Empires III"
#       3 for url in units_urls:
# ----> 4     infoboxes = get_infoboxes(url, TARGET_GAME)
#       5     for infobox in infoboxes:
#       6         try:
#
# Cell In[5], line 5, in get_infoboxes(url, target_game)
#       1 def get_infoboxes(url, target_game):
#       3     try:
# ----> 5         unit_html = fetch_page_content(url)
#       6         unit_soup = bs(unit_html, "html.parser")
#       7         infoboxes = unit_soup.find_all("aside", class_="portable-infobox")
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\src\utils.py:24, in fetch_page_content(url)
#      22 def fetch_page_content(url):
#      23     """Fetches the HTML content of the page."""
# ---> 24     response = requests.get(url)
#      25     try:
#      26         response.raise_for_status()
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\.venv\Lib\site-packages\urllib3\util\ssl_.py:446, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444 if ca_certs or ca_cert_dir or ca_cert_data:
#     445     try:
# --> 446         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447     except OSError as e:
#     448         raise SSLError(e) from e
#
# KeyboardInterrupt:
