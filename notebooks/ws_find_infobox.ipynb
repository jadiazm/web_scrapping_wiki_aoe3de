# %%
import os
import sys

project_path = os.path.abspath("..")

sys.path.append(project_path)

# %%
from urllib.parse import urlparse

from bs4 import BeautifulSoup as bs

from src.scrap_hrefs import get_section_hrefs
from src.scrap_infobox import extract_unit_data, find_infobox
from src.utils import fetch_page_content

# %% [markdown]
# ## Implementation

# %%
def get_units_urls(url) -> list:
    
    units_url = url + "wiki/Unit_(Age_of_Empires_III)"
    unit_list_html = fetch_page_content(units_url)
    href_soup = bs(unit_list_html, "html.parser")

    content = href_soup.find('div', class_='mw-parser-output')
    h2s = content.find_all('h2', recursive=False)
    sections = [h2.find('span', class_='mw-headline', recursive=False).text for h2 in h2s]
    # section_unit_hrefs = {section: get_units_hrefs(section, content) for section in sections}
    units_urls = {
        unit: url + href
        for section in sections
        for unit, href in get_section_hrefs(section, content).items()
    }

    return units_urls

# %%
url = "https://ageofempires.fandom.com/"

units_urls = get_units_urls(url)
units_urls
# Out:
# {'Axehilt the Tame Tiger': 'https://ageofempires.fandom.com//wiki/Tiger#Axehilt_the_Tame_Tiger',
#  'Buck the Tame Wolf': 'https://ageofempires.fandom.com//wiki/Wolf#Buck_the_Tame_Wolf',
#  'Carib Blowgun Ambusher': 'https://ageofempires.fandom.com//wiki/Carib_Blowgunner',
#  'Fang the Tame Coyote': 'https://ageofempires.fandom.com//wiki/Coyote#Fang_the_Tame_Coyote',
#  'Disciple': 'https://ageofempires.fandom.com//wiki/Disciple',
#  'Eagle Scout': 'https://ageofempires.fandom.com//wiki/Eagle_Scout_(Age_of_Empires_III)',
#  'Envoy': 'https://ageofempires.fandom.com//wiki/Envoy_(Age_of_Empires_III)',
#  'Hot Air Balloon': 'https://ageofempires.fandom.com//wiki/Hot_Air_Balloon',
#  'Janey the Pet Jaguar': 'https://ageofempires.fandom.com//wiki/Jaguar#Janey_the_Pet_Jaguar',
#  'Nootka War Chief': 'https://ageofempires.fandom.com//wiki/Nootka_War_Chief',
#  'Peruvian Dog': 'https://ageofempires.fandom.com//wiki/Dog#Peruvian_Dog',
#  'Wagner the Pet White Tiger': 'https://ageofempires.fandom.com//wiki/White_Tiger_(Age_of_Empires_III)#Wagner_the_Pet_White_Tiger',
#  'War Dog': 'https://ageofempires.fandom.com//wiki/Dog#Age_of_Empires_III',
#  'Architect': 'https://ageofempires.fandom.com//wiki/Architect',
#  'Barbary Warrior': 'https://ageofempires.fandom.com//wiki/Barbary_Warrior',
#  'Bashibozuk': 'https://ageofempires.fandom.com//wiki/Bashibozuk',
#  'Californio': 'https://ageofempires.fandom.com//wiki/Californio',
#  'Buttercup the Pet Cougar': 'https://ageofempires.fandom.com//wiki/Cougar#Buttercup',
#  'Coureur des Bois': 'https://ageofempires.fandom.com//wiki/Coureur_des_Bois',
#  'Cuerudo': 'https://ageofempires.fandom.com//wiki/Cuerudo',
#  'Chasqui': 'https://ageofempires.fandom.com//wiki/Chasqui',
#  'Eclaireur': 'https://ageofempires.fandom.com//wiki/Eclaireur',
#  'Filibuster': 'https://ageofempires.fandom.com//wiki/Filibuster',
#  'Hindu Villager': 'https://ageofempires.fandom.com//wiki/Hindu_Villager',
#  'Javanese Spearman': 'https://ageofempires.fandom.com//wiki/Javanese_Spearman',
#  'Karelian Jaeger': 'https://ageofempires.fandom.com//wiki/Skirmisher_(Age_of_Empires_III)#Karelian_Jaeger',
#  'Merchant': 'https://ageofempires.fandom.com//wiki/Merchant_(Age_of_Empires_III)',
#  'Militiaman': 'https://ageofempires.fandom.com//wiki/Militiaman',
#  'Native Scout': 'https://ageofempires.fandom.com//wiki/Native_Scout',
#  'Revolutionary': 'https://ageofempires.fandom.com//wiki/Revolutionary',
#  'Settler': 'https://ageofempires.fandom.com//wiki/Settler',
#  'Villager': 'https://ageofempires.fandom.com//wiki/Villager_(Age_of_Empires_III)',
#  'Volunteer': 'https://ageofempires.fandom.com//wiki/State_Militia',
#  'Yörük': 'https://ageofempires.fandom.com//wiki/Y%C3%B6r%C3%BCk',
#  'Settler Wagon': 'https://ageofempires.fandom.com//wiki/Settler_Wagon',
#  'Cow': 'https://ageofempires.fandom.com//wiki/Cow#Age_of_Empires_III',
#  'Goat': 'https://ageofempires.fandom.com//wiki/Goat#Age_of_Empires_III',
#  'Llama': 'https://ageofempires.fandom.com//wiki/Llama#Age_of_Empires_III',
#  'Sheep': 'https://ageofempires.fandom.com//wiki/Sheep#Age_of_Empires_III',
#  'Atakebune': 'https://ageofempires.fandom.com//wiki/Atakebune_(Age_of_Empires_III)',
#  'Bandit Catamaran': 'https://ageofempires.fandom.com//wiki/Bandit_Catamaran',
#  'Battle Canoe': 'https://ageofempires.fandom.com//wiki/Battle_Canoe',
#  'Battleship': 'https://ageofempires.fandom.com//wiki/Battleship',
#  'Cannon Boat': 'https://ageofempires.fandom.com//wiki/Cannon_Boat',
#  'Canoe': 'https://ageofempires.fandom.com//wiki/Canoe_(Age_of_Empires_III)',
#  'Caravel': 'https://ageofempires.fandom.com//wiki/Caravel_(Age_of_Empires_III)',
#  'Chincha Raft': 'https://ageofempires.fandom.com//wiki/Chincha_Raft',
#  'Fire Junk': 'https://ageofempires.fandom.com//wiki/Fire_Junk',
#  'Fishing Boat': 'https://ageofempires.fandom.com//wiki/Fishing_Boat_(Age_of_Empires_III)',
#  'Fishing Canoe': 'https://ageofempires.fandom.com//wiki/Fishing_Canoe',
#  'Fire Ship': 'https://ageofempires.fandom.com//wiki/Fire_Ship_(Age_of_Empires_III)',
#  'Fluyt': 'https://ageofempires.fandom.com//wiki/Fluyt',
#  'Frigate': 'https://ageofempires.fandom.com//wiki/Frigate',
#  'Fuchuan': 'https://ageofempires.fandom.com//wiki/Fuchuan',
#  'Fune': 'https://ageofempires.fandom.com//wiki/Fune',
#  'Galleass': 'https://ageofempires.fandom.com//wiki/Galleass_(Age_of_Empires_III)',
#  'Galleon': 'https://ageofempires.fandom.com//wiki/Galleon_(Age_of_Empires_III)',
#  'Galley': 'https://ageofempires.fandom.com//wiki/Galley_(Age_of_Empires_III)',
#  'Ironclad': 'https://ageofempires.fandom.com//wiki/Ironclad_(Age_of_Empires_III)',
#  'Marathan Catamaran': 'https://ageofempires.fandom.com//wiki/Marathan_Catamaran',
#  'Monitor': 'https://ageofempires.fandom.com//wiki/Monitor',
#  'Order Galley': 'https://ageofempires.fandom.com//wiki/Order_Galley',
#  'Privateer': 'https://ageofempires.fandom.com//wiki/Privateer',
#  'Sloop': 'https://ageofempires.fandom.com//wiki/Sloop',
#  'Steamer': 'https://ageofempires.fandom.com//wiki/Steamer',
#  'Tekkousen': 'https://ageofempires.fandom.com//wiki/Tekkousen',
#  'Tlaloc Canoe': 'https://ageofempires.fandom.com//wiki/Tlaloc_Canoe',
#  'War Canoe': 'https://ageofempires.fandom.com//wiki/War_Canoe',
#  'War Dhow': 'https://ageofempires.fandom.com//wiki/War_Dhow',
#  'War Junk': 'https://ageofempires.fandom.com//wiki/War_Junk',
#  'Wokou Junk': 'https://ageofempires.fandom.com//wiki/Wokou_Junk',
#  'Xebec': 'https://ageofempires.fandom.com//wiki/Xebec',
#  'Akan Ankobia': 'https://ageofempires.fandom.com//wiki/Akan_Ankobia',
#  'Apache Cavalry': 'https://ageofempires.fandom.com//wiki/Apache_Cavalry',
#  'Aztec Eagle Warrior': 'https://ageofempires.fandom.com//wiki/Aztec_Eagle_Warrior',
#  'Aztec Jaguar Warrior': 'https://ageofempires.fandom.com//wiki/Aztec_Jaguar_Warrior',
#  'Berber Camel Rider': 'https://ageofempires.fandom.com//wiki/Berber_Camel_Rider',
#  'Berber Nomad': 'https://ageofempires.fandom.com//wiki/Berber_Nomad',
#  'Berber Salt Camel': 'https://ageofempires.fandom.com//wiki/Berber_Salt_Camel',
#  'Black Brunswicker': 'https://ageofempires.fandom.com//wiki/Black_Brunswicker',
#  'Boyar': 'https://ageofempires.fandom.com//wiki/Boyar_(Age_of_Empires_III)',
#  'Captured Mortar': 'https://ageofempires.fandom.com//wiki/Captured_Mortar',
#  'Carib Blowgunner': 'https://ageofempires.fandom.com//wiki/Carib_Blowgunner',
#  'Chakram Thrower': 'https://ageofempires.fandom.com//wiki/Chakram_Thrower_(Age_of_Empires_III)',
#  'Cherokee Rifleman': 'https://ageofempires.fandom.com//wiki/Cherokee_Rifleman',
#  'Chevauleger': 'https://ageofempires.fandom.com//wiki/Chevauleger',
#  'Cheyenne Rider': 'https://ageofempires.fandom.com//wiki/Cheyenne_Rider',
#  'Comanche Horse Archer': 'https://ageofempires.fandom.com//wiki/Comanche_Horse_Archer',
#  'Conquistador': 'https://ageofempires.fandom.com//wiki/Conquistador_(Age_of_Empires_III)',
#  'Cree Tracker': 'https://ageofempires.fandom.com//wiki/Cree_Tracker',
#  'Cree Coureur des Bois': 'https://ageofempires.fandom.com//wiki/Cree_Coureur_des_Bois',
#  'Drummer': 'https://ageofempires.fandom.com//wiki/Drummer',
#  'Evzone': 'https://ageofempires.fandom.com//wiki/Evzone',
#  'Haudenosaunee Mantlet': 'https://ageofempires.fandom.com//wiki/Haudenosaunee_Mantlet',
#  'Haudenosaunee Tomahawk': 'https://ageofempires.fandom.com//wiki/Haudenosaunee_Tomahawk',
#  'Healer': 'https://ageofempires.fandom.com//wiki/Healer_(Age_of_Empires_III)',
#  'Huron Mantlet': 'https://ageofempires.fandom.com//wiki/Huron_Mantlet',
#  'Klamath Rifleman': 'https://ageofempires.fandom.com//wiki/Klamath_Rifleman',
#  'Line Infantry': 'https://ageofempires.fandom.com//wiki/Line_Infantry',
#  'Lipka Tatar': 'https://ageofempires.fandom.com//wiki/Lipka_Tatar',
#  'Mapuche Ironwood Clubman': 'https://ageofempires.fandom.com//wiki/Mapuche_Ironwood_Clubman',
#  'Mapuche Bolas Rider': 'https://ageofempires.fandom.com//wiki/Mapuche_Bolas_Rider',
#  'Maya Holcan Javelineer': 'https://ageofempires.fandom.com//wiki/Maya_Holcan_Javelineer',
#  'Mountain Trooper': 'https://ageofempires.fandom.com//wiki/Mountain_Trooper',
#  'Mounted Infantry': 'https://ageofempires.fandom.com//wiki/Mounted_Infantry',
#  'Navajo Rifleman': 'https://ageofempires.fandom.com//wiki/Navajo_Rifleman',
#  'Nootka Clubman': 'https://ageofempires.fandom.com//wiki/Nootka_Clubman',
#  'Northern Musketeer': 'https://ageofempires.fandom.com//wiki/Northern_Musketeer',
#  'Qizilbash': 'https://ageofempires.fandom.com//wiki/Qizilbash',
#  'Quechua Bolas Warrior': 'https://ageofempires.fandom.com//wiki/Quechua_Bolas_Warrior',
#  'Quechua Huaminca': 'https://ageofempires.fandom.com//wiki/Quechua_Huaminca',
#  'Rattan Shield': 'https://ageofempires.fandom.com//wiki/Rattan_Shield',
#  'Royal Arquebusier': 'https://ageofempires.fandom.com//wiki/Royal_Arquebusier',
#  'Royal Dragoon': 'https://ageofempires.fandom.com//wiki/Royal_Dragoon',
#  'Royal Huntsman': 'https://ageofempires.fandom.com//wiki/Royal_Huntsman',
#  'Royal Musketeer': 'https://ageofempires.fandom.com//wiki/Royal_Musketeer',
#  'Saxon Cuirassier': 'https://ageofempires.fandom.com//wiki/Saxon_Cuirassier',
#  'Seminole Sharktooth Bowman': 'https://ageofempires.fandom.com//wiki/Seminole_Sharktooth_Bowman',
#  'Shock Rider': 'https://ageofempires.fandom.com//wiki/Shock_Rider',
#  'Sohei Naginata': 'https://ageofempires.fandom.com//wiki/Sohei_Naginata',
#  'Somali Darood Militia': 'https://ageofempires.fandom.com//wiki/Somali_Darood_Militia',
#  'Somali Issa Warrior': 'https://ageofempires.fandom.com//wiki/Somali_Issa_Warrior',
#  'Sudanese Dervish': 'https://ageofempires.fandom.com//wiki/Sudanese_Dervish',
#  'Tatar Archer': 'https://ageofempires.fandom.com//wiki/Tatar_Archer',
#  'Tengri Wolf': 'https://ageofempires.fandom.com//wiki/Tengri_Wolf',
#  'Tiger Claw': 'https://ageofempires.fandom.com//wiki/Tiger_Claw',
#  'Totenkopf Hussar': 'https://ageofempires.fandom.com//wiki/Totenkopf_Hussar',
#  'Trabant': 'https://ageofempires.fandom.com//wiki/Trabant',
#  'Tupi Blackwood Archer': 'https://ageofempires.fandom.com//wiki/Tupi_Blackwood_Archer',
#  'Winged Hussar': 'https://ageofempires.fandom.com//wiki/Winged_Hussar_(Age_of_Empires_III)',
#  'War Elephant': 'https://ageofempires.fandom.com//wiki/War_Elephant_(Age_of_Empires_III)',
#  'Yoruba Oyo Legionary': 'https://ageofempires.fandom.com//wiki/Yoruba_Oyo_Legionary',
#  'Yoruba Eso Rider': 'https://ageofempires.fandom.com//wiki/Yoruba_Eso_Rider',
#  'Zapotec Lightning Warrior': 'https://ageofempires.fandom.com//wiki/Zapotec_Lightning_Warrior',
#  'Imam': 'https://ageofempires.fandom.com//wiki/Imam_(Age_of_Empires_III)',
#  'Missionary': 'https://ageofempires.fandom.com//wiki/Missionary_(Age_of_Empires_III)',
#  'Muhbir': 'https://ageofempires.fandom.com//wiki/Muhbir',
#  'Padre': 'https://ageofempires.fandom.com//wiki/Padre',
#  'Priest': 'https://ageofempires.fandom.com//wiki/Priest_(Age_of_Empires_III)',
#  'Spy': 'https://ageofempires.fandom.com//wiki/Spy_(Age_of_Empires_III)',
#  'Surgeon': 'https://ageofempires.fandom.com//wiki/Surgeon',
#  'Papal Guard': 'https://ageofempires.fandom.com//wiki/Papal_Guard',
#  'Papal Lancer': 'https://ageofempires.fandom.com//wiki/Papal_Lancer',
#  'Papal Zouave': 'https://ageofempires.fandom.com//wiki/Papal_Zouave',
#  'Schiavone': 'https://ageofempires.fandom.com//wiki/Schiavone',
#  'Ashigaru Musketeer': 'https://ageofempires.fandom.com//wiki/Ashigaru_Musketeer',
#  'Azap': 'https://ageofempires.fandom.com//wiki/Azap',
#  'Bersagliere': 'https://ageofempires.fandom.com//wiki/Bersagliere',
#  'Carolean': 'https://ageofempires.fandom.com//wiki/Carolean',
#  'Cassador': 'https://ageofempires.fandom.com//wiki/Cassador',
#  'Corsair Marksman': 'https://ageofempires.fandom.com//wiki/Corsair_Marksman',
#  'Crossbowman': 'https://ageofempires.fandom.com//wiki/Crossbowman_(Age_of_Empires_III)',
#  'Cruzob Avenger': 'https://ageofempires.fandom.com//wiki/Salteador#Cruzob_Avenger',
#  'Cruzob Infantry': 'https://ageofempires.fandom.com//wiki/Cruzob_Infantry',
#  'Doppelsoldner': 'https://ageofempires.fandom.com//wiki/Doppelsoldner',
#  'Gurkha': 'https://ageofempires.fandom.com//wiki/Gurkha',
#  'Halberdier': 'https://ageofempires.fandom.com//wiki/Halberdier_(Age_of_Empires_III)',
#  'Insurgente': 'https://ageofempires.fandom.com//wiki/Insurgente',
#  'Janissary': 'https://ageofempires.fandom.com//wiki/Janissary_(Age_of_Empires_III)',
#  'Landwehr': 'https://ageofempires.fandom.com//wiki/Landwehr',
#  'Longbowman': 'https://ageofempires.fandom.com//wiki/Longbowman_(Age_of_Empires_III)',
#  'Musketeer': 'https://ageofempires.fandom.com//wiki/Musketeer',
#  'Nizam Fusilier': 'https://ageofempires.fandom.com//wiki/Nizam_Fusilier',
#  'Ordinance Rifleman': 'https://ageofempires.fandom.com//wiki/Ordinance_Rifleman',
#  'Pavisier': 'https://ageofempires.fandom.com//wiki/Pavisier',
#  'Pikeman': 'https://ageofempires.fandom.com//wiki/Pikeman_(Age_of_Empires_III)',
#  'Poruchik': 'https://ageofempires.fandom.com//wiki/Poruchik',
#  'Rajput': 'https://ageofempires.fandom.com//wiki/Rajput',
#  'Ranger': 'https://ageofempires.fandom.com//wiki/Ranger',
#  'Regular': 'https://ageofempires.fandom.com//wiki/Regular',
#  'Rekrut': 'https://ageofempires.fandom.com//wiki/Rekrut',
#  'Rodelero': 'https://ageofempires.fandom.com//wiki/Rodelero',
#  'Salteador': 'https://ageofempires.fandom.com//wiki/Salteador',
#  'Samurai': 'https://ageofempires.fandom.com//wiki/Samurai_(Age_of_Empires_III)',
#  'Sepoy': 'https://ageofempires.fandom.com//wiki/Sepoy',
#  'Sharpshooter': 'https://ageofempires.fandom.com//wiki/Sharpshooter',
#  'Skirmisher': 'https://ageofempires.fandom.com//wiki/Skirmisher_(Age_of_Empires_III)',
#  'Soldado': 'https://ageofempires.fandom.com//wiki/Soldado',
#  'State Militia': 'https://ageofempires.fandom.com//wiki/State_Militia',
#  'Strelet': 'https://ageofempires.fandom.com//wiki/Strelet',
#  'Yumi Archer': 'https://ageofempires.fandom.com//wiki/Yumi_Archer',
#  'Hospitaller': 'https://ageofempires.fandom.com//wiki/Hospitaller',
#  'Sentinel': 'https://ageofempires.fandom.com//wiki/Sentinel_(Age_of_Empires_III)',
#  'Carbine Cavalry': 'https://ageofempires.fandom.com//wiki/Carbine_Cavalry',
#  'Cavalry Archer': 'https://ageofempires.fandom.com//wiki/Cavalry_Archer_(Age_of_Empires_III)',
#  'Chinaco': 'https://ageofempires.fandom.com//wiki/Chinaco',
#  'Cossack': 'https://ageofempires.fandom.com//wiki/Cossack',
#  'Cuirassier': 'https://ageofempires.fandom.com//wiki/Cuirassier',
#  'Deli': 'https://ageofempires.fandom.com//wiki/Deli',
#  'Dragoon': 'https://ageofempires.fandom.com//wiki/Dragoon',
#  'Hakkapelit': 'https://ageofempires.fandom.com//wiki/Hakkapelit',
#  'Hussar': 'https://ageofempires.fandom.com//wiki/Hussar_(Age_of_Empires_III)',
#  'Lancer': 'https://ageofempires.fandom.com//wiki/Lancer_(Age_of_Empires_III)',
#  'Mounted Granadero': 'https://ageofempires.fandom.com//wiki/Mounted_Granadero',
#  'Naginata Rider': 'https://ageofempires.fandom.com//wiki/Naginata_Rider',
#  'Oprichnik': 'https://ageofempires.fandom.com//wiki/Oprichnik',
#  'Ruyter': 'https://ageofempires.fandom.com//wiki/Ruyter',
#  'Uhlan': 'https://ageofempires.fandom.com//wiki/Uhlan',
#  'War Wagon': 'https://ageofempires.fandom.com//wiki/War_Wagon_(Age_of_Empires_III)',
#  'Yabusame': 'https://ageofempires.fandom.com//wiki/Yabusame',
#  'Abus Gunner': 'https://ageofempires.fandom.com//wiki/Abus_Gunner',
#  'Culverin': 'https://ageofempires.fandom.com//wiki/Culverin_(Age_of_Empires_III)',
#  'Falconet': 'https://ageofempires.fandom.com//wiki/Falconet',
#  'Fire Thrower': 'https://ageofempires.fandom.com//wiki/Fire_Thrower',
#  'Gatling Gun': 'https://ageofempires.fandom.com//wiki/Gatling_Gun',
#  'Grenadier': 'https://ageofempires.fandom.com//wiki/Grenadier_(Age_of_Empires_III)',
#  'Hoop Thrower': 'https://ageofempires.fandom.com//wiki/Hoop_Thrower',
#  'Horse Artillery': 'https://ageofempires.fandom.com//wiki/Horse_Artillery',
#  'Humbaraci': 'https://ageofempires.fandom.com//wiki/Humbaraci',
#  'Leather Cannon': 'https://ageofempires.fandom.com//wiki/Leather_Cannon',
#  'Mortar': 'https://ageofempires.fandom.com//wiki/Mortar',
#  'Organ Gun': 'https://ageofempires.fandom.com//wiki/Organ_Gun_(Age_of_Empires_III)',
#  'Petard': 'https://ageofempires.fandom.com//wiki/Petard_(Age_of_Empires_III)',
#  'Quaker Gun': 'https://ageofempires.fandom.com//wiki/Quaker_Gun',
#  'Rocket': 'https://ageofempires.fandom.com//wiki/Rocket',
#  'Great Bombard': 'https://ageofempires.fandom.com//wiki/Great_Bombard_(Age_of_Empires_III)',
#  'Heavy Cannon': 'https://ageofempires.fandom.com//wiki/Heavy_Cannon',
#  'Papal Bombard': 'https://ageofempires.fandom.com//wiki/Papal_Bombard',
#  'Magyar Hussar': 'https://ageofempires.fandom.com//wiki/Hussar_(Age_of_Empires_III)#Magyar_Hussar',
#  'Armored Pistoleer': 'https://ageofempires.fandom.com//wiki/Armored_Pistoleer',
#  'Arsonist': 'https://ageofempires.fandom.com//wiki/Arsonist',
#  'Askari': 'https://ageofempires.fandom.com//wiki/Askari',
#  'Barbary Corsair': 'https://ageofempires.fandom.com//wiki/Barbary_Corsair',
#  'Bandido': 'https://ageofempires.fandom.com//wiki/Bandido',
#  'Black Rider': 'https://ageofempires.fandom.com//wiki/Black_Rider_(Age_of_Empires_III)',
#  'Bosniak': 'https://ageofempires.fandom.com//wiki/Bosniak',
#  'Cannoneer': 'https://ageofempires.fandom.com//wiki/Cannoneer',
#  'Comanchero': 'https://ageofempires.fandom.com//wiki/Comanchero',
#  'Cossack Daredevil': 'https://ageofempires.fandom.com//wiki/Cossack_Daredevil',
#  'Cowboy': 'https://ageofempires.fandom.com//wiki/Cowboy_(Saloon)',
#  'Crabat': 'https://ageofempires.fandom.com//wiki/Crabat',
#  'Cuatrero': 'https://ageofempires.fandom.com//wiki/Cuatrero',
#  'Dacoit': 'https://ageofempires.fandom.com//wiki/Dacoit',
#  'Dahomey Amazon': 'https://ageofempires.fandom.com//wiki/Dahomey_Amazon',
#  'Desperado': 'https://ageofempires.fandom.com//wiki/Desperado',
#  'Elmetto': 'https://ageofempires.fandom.com//wiki/Elmetto',
#  'Fusilier': 'https://ageofempires.fandom.com//wiki/Fusilier',
#  'Gatling Camel': 'https://ageofempires.fandom.com//wiki/Gatling_Camel',
#  'Giant Grenadier': 'https://ageofempires.fandom.com//wiki/Giant_Grenadier',
#  'Gunslinger': 'https://ageofempires.fandom.com//wiki/Gunslinger',
#  'Hackapell': 'https://ageofempires.fandom.com//wiki/Hackapell',
#  'Hajduk': 'https://ageofempires.fandom.com//wiki/Hajduk',
#  'Harquebusier': 'https://ageofempires.fandom.com//wiki/Harquebusier',
#  'Highwayman': 'https://ageofempires.fandom.com//wiki/Highwayman',
#  'Highlander': 'https://ageofempires.fandom.com//wiki/Highlander',
#  'Inquisitor': 'https://ageofempires.fandom.com//wiki/Inquisitor',
#  'Irish Brigadier': 'https://ageofempires.fandom.com//wiki/Irish_Brigadier',
#  'Iron Troop': 'https://ageofempires.fandom.com//wiki/Iron_Troop',
#  'Jaeger': 'https://ageofempires.fandom.com//wiki/Jaeger',
#  'Jat Lancer': 'https://ageofempires.fandom.com//wiki/Jat_Lancer',
#  'Kanuri Guard': 'https://ageofempires.fandom.com//wiki/Kanuri_Guard',
#  'Landsknecht': 'https://ageofempires.fandom.com//wiki/Landsknecht_(Age_of_Empires_III)',
#  "Li'l Bombard": 'https://ageofempires.fandom.com//wiki/Li%27l_Bombard',
#  'Maigadi': 'https://ageofempires.fandom.com//wiki/Maigadi',
#  'Mameluke': 'https://ageofempires.fandom.com//wiki/Mameluke_(Age_of_Empires_III)',
#  'Manchu': 'https://ageofempires.fandom.com//wiki/Manchu',
#  'Mounted Rifleman': 'https://ageofempires.fandom.com//wiki/Mounted_Rifleman',
#  'Napoleon Gun': 'https://ageofempires.fandom.com//wiki/Napoleon_Gun',
#  'Ninja': 'https://ageofempires.fandom.com//wiki/Ninja_(Age_of_Empires_III)',
#  'Owlhoot': 'https://ageofempires.fandom.com//wiki/Owlhoot',
#  'Pandour': 'https://ageofempires.fandom.com//wiki/Pandour',
#  'Pirate': 'https://ageofempires.fandom.com//wiki/Pirate_(Age_of_Empires_III)',
#  'Pistolero': 'https://ageofempires.fandom.com//wiki/Pistolero',
#  'Renegado': 'https://ageofempires.fandom.com//wiki/Renegado',
#  'Ronin': 'https://ageofempires.fandom.com//wiki/Ronin',
#  'Royal Horseman': 'https://ageofempires.fandom.com//wiki/Royal_Horseman',
#  'Sennar Horseman': 'https://ageofempires.fandom.com//wiki/Sennar_Horseman',
#  'Stradiot': 'https://ageofempires.fandom.com//wiki/Stradiot',
#  'Swiss Pikeman': 'https://ageofempires.fandom.com//wiki/Swiss_Pikeman',
#  'Thuggee': 'https://ageofempires.fandom.com//wiki/Thuggee',
#  'Wokou Horseman': 'https://ageofempires.fandom.com//wiki/Wokou_Horseman',
#  'Wokou Monk': 'https://ageofempires.fandom.com//wiki/Wokou_Monk',
#  'Wokou Pirate': 'https://ageofempires.fandom.com//wiki/Wokou_Pirate',
#  'Wokou Ronin': 'https://ageofempires.fandom.com//wiki/Wokou_Ronin',
#  'Yojimbo': 'https://ageofempires.fandom.com//wiki/Yojimbo',
#  'Zenata Rider': 'https://ageofempires.fandom.com//wiki/Zenata_Rider',
#  'Zouave': 'https://ageofempires.fandom.com//wiki/Zouave',
#  'Aenna': 'https://ageofempires.fandom.com//wiki/Aenna',
#  'Cetan Bow': 'https://ageofempires.fandom.com//wiki/Cetan_Bow',
#  'Chimu Runner': 'https://ageofempires.fandom.com//wiki/Chimu_Runner',
#  'Club Warrior': 'https://ageofempires.fandom.com//wiki/Club_Warrior',
#  'Coyote Runner': 'https://ageofempires.fandom.com//wiki/Coyote_Runner',
#  'Forest Prowler': 'https://ageofempires.fandom.com//wiki/Forest_Prowler',
#  'Jungle Bowman': 'https://ageofempires.fandom.com//wiki/Jungle_Bowman',
#  'Otontin Slinger': 'https://ageofempires.fandom.com//wiki/Otontin_Slinger',
#  'Plumed Spearman': 'https://ageofempires.fandom.com//wiki/Plumed_Spearman',
#  'Puma Spearman': 'https://ageofempires.fandom.com//wiki/Puma_Spearman',
#  'Tomahawk': 'https://ageofempires.fandom.com//wiki/Tomahawk',
#  'Wakina Rifle': 'https://ageofempires.fandom.com//wiki/Wakina_Rifle',
#  'Axe Rider': 'https://ageofempires.fandom.com//wiki/Axe_Rider',
#  'Bow Rider': 'https://ageofempires.fandom.com//wiki/Bow_Rider',
#  'Kanya Horseman': 'https://ageofempires.fandom.com//wiki/Kanya_Horseman',
#  'Musket Rider': 'https://ageofempires.fandom.com//wiki/Musket_Rider',
#  'Rifle Rider': 'https://ageofempires.fandom.com//wiki/Rifle_Rider',
#  'Tashunke Prowler': 'https://ageofempires.fandom.com//wiki/Tashunke_Prowler',
#  'Light Cannon': 'https://ageofempires.fandom.com//wiki/Light_Cannon',
#  'Mantlet': 'https://ageofempires.fandom.com//wiki/Mantlet',
#  'Ram': 'https://ageofempires.fandom.com//wiki/Ram_(Age_of_Empires_III)',
#  'Arrow Knight': 'https://ageofempires.fandom.com//wiki/Arrow_Knight',
#  'Eagle Runner Knight': 'https://ageofempires.fandom.com//wiki/Eagle_Runner_Knight',
#  'Jaguar Prowl Knight': 'https://ageofempires.fandom.com//wiki/Jaguar_Prowl_Knight',
#  'Bolas Warrior': 'https://ageofempires.fandom.com//wiki/Bolas_Warrior',
#  'Huaraca': 'https://ageofempires.fandom.com//wiki/Huaraca',
#  'Maceman': 'https://ageofempires.fandom.com//wiki/Maceman_(Age_of_Empires_III)',
#  'Priestess': 'https://ageofempires.fandom.com//wiki/Priestess_(Age_of_Empires_III)',
#  'Skull Knight': 'https://ageofempires.fandom.com//wiki/Skull_Knight',
#  'Tokala Soldier': 'https://ageofempires.fandom.com//wiki/Tokala_Soldier',
#  'Warrior': 'https://ageofempires.fandom.com//wiki/Warrior',
#  'Warrior Priest': 'https://ageofempires.fandom.com//wiki/Warrior_Priest_(Age_of_Empires_III)',
#  'Water Buffalo': 'https://ageofempires.fandom.com//wiki/Water_Buffalo#Age_of_Empires_III',
#  'Sacred Cow': 'https://ageofempires.fandom.com//wiki/Sacred_Cow',
#  'Forbidden Army': 'https://ageofempires.fandom.com//wiki/Forbidden_Army',
#  'Imperial Army': 'https://ageofempires.fandom.com//wiki/Imperial_Army',
#  'Ming Army': 'https://ageofempires.fandom.com//wiki/Ming_Army',
#  'Old Han Army': 'https://ageofempires.fandom.com//wiki/Old_Han_Army',
#  'Standard Army': 'https://ageofempires.fandom.com//wiki/Standard_Army',
#  'Territorial Army': 'https://ageofempires.fandom.com//wiki/Territorial_Army',
#  'Howdah': 'https://ageofempires.fandom.com//wiki/Howdah_(Age_of_Empires_III)',
#  'Mahout Lancer': 'https://ageofempires.fandom.com//wiki/Mahout_Lancer',
#  'Sowar': 'https://ageofempires.fandom.com//wiki/Sowar',
#  'Zamburak': 'https://ageofempires.fandom.com//wiki/Zamburak',
#  'Black Flag Army': 'https://ageofempires.fandom.com//wiki/Black_Flag_Army',
#  'Flail Elephant': 'https://ageofempires.fandom.com//wiki/Flail_Elephant',
#  'Flamethrower': 'https://ageofempires.fandom.com//wiki/Flamethrower_(Age_of_Empires_III)',
#  'Flaming Arrow': 'https://ageofempires.fandom.com//wiki/Flaming_Arrow',
#  'Hand Mortar': 'https://ageofempires.fandom.com//wiki/Hand_Mortar',
#  'Mongolian Army': 'https://ageofempires.fandom.com//wiki/Mongolian_Army',
#  'Morutaru': 'https://ageofempires.fandom.com//wiki/Morutaru',
#  'Siege Elephant': 'https://ageofempires.fandom.com//wiki/Siege_Elephant_(Age_of_Empires_III)',
#  'Flying Crow': 'https://ageofempires.fandom.com//wiki/Flying_Crow',
#  'Daimyo Kiyomasa': 'https://ageofempires.fandom.com//wiki/Daimyo',
#  'Shogun Tokugawa': 'https://ageofempires.fandom.com//wiki/Tokugawa_Ieyasu#In-game_unit_(skirmish)',
#  'Mansabdar Flail Elephant': 'https://ageofempires.fandom.com//wiki/Flail_Elephant#Mansabdar_Flail_Elephant',
#  'Mansabdar Gurkha': 'https://ageofempires.fandom.com//wiki/Gurkha#Mansabdar_Gurkha',
#  'Mansabdar Howdah': 'https://ageofempires.fandom.com//wiki/Howdah_(Age_of_Empires_III)#Mansabdar_Howdah',
#  'Mansabdar Mahout': 'https://ageofempires.fandom.com//wiki/Mahout_Lancer#Mansabdar_Mahout',
#  'Mansabdar Rajput': 'https://ageofempires.fandom.com//wiki/Rajput#Mansabdar_Rajput',
#  'Mansabdar Sepoy': 'https://ageofempires.fandom.com//wiki/Sepoy#Mansabdar_Sepoy',
#  'Mansabdar Sowar': 'https://ageofempires.fandom.com//wiki/Sowar#Mansabdar_Sowar',
#  'Mansabdar Urumi': 'https://ageofempires.fandom.com//wiki/Urumi_Swordsman_(Age_of_Empires_III)#Mansabdar_Urumi',
#  'Mansabdar Zamburak': 'https://ageofempires.fandom.com//wiki/Zamburak#Mansabdar_Zamburak',
#  'Mansabdar Siege Elephant': 'https://ageofempires.fandom.com//wiki/Siege_Elephant_(Age_of_Empires_III)#Mansabdar_Siege_Elephant',
#  'Fulani Archer': 'https://ageofempires.fandom.com//wiki/Fulani_Archer',
#  'Gascenya': 'https://ageofempires.fandom.com//wiki/Gascenya',
#  'Javelin Rider': 'https://ageofempires.fandom.com//wiki/Javelin_Rider',
#  'Lifidi Knight': 'https://ageofempires.fandom.com//wiki/Lifidi_Knight',
#  'Neftenya': 'https://ageofempires.fandom.com//wiki/Neftenya',
#  'Oromo Warrior': 'https://ageofempires.fandom.com//wiki/Oromo_Warrior',
#  'Raider': 'https://ageofempires.fandom.com//wiki/Raider_(Age_of_Empires_III)',
#  'Shotel Warrior': 'https://ageofempires.fandom.com//wiki/Shotel_Warrior_(Age_of_Empires_III)',
#  'Bank Wagon': 'https://ageofempires.fandom.com//wiki/Bank_Wagon',
#  'Covered Wagon': 'https://ageofempires.fandom.com//wiki/Covered_Wagon',
#  'Estate Wagon': 'https://ageofempires.fandom.com//wiki/Estate_Wagon',
#  'Mill Wagon': 'https://ageofempires.fandom.com//wiki/Mill_Wagon',
#  'Outpost Wagon': 'https://ageofempires.fandom.com//wiki/Outpost_Wagon',
#  'Trading Post Wagon': 'https://ageofempires.fandom.com//wiki/Trading_Post_Wagon',
#  'Hatamoto Samurai': 'https://ageofempires.fandom.com//wiki/Ronin',
#  'Konsha Yamabushi': 'https://ageofempires.fandom.com//wiki/Yamabushi',
#  'Ninjutsu-Zukai': 'https://ageofempires.fandom.com//wiki/Ninja_(Age_of_Empires_III)',
#  'Shinobi-no-Mono': 'https://ageofempires.fandom.com//wiki/Shinobi_(Age_of_Empires_III)',
#  "Morgan's Flagship": 'https://ageofempires.fandom.com//wiki/Morgan%27s_Flagship',
#  "Lizzie's Flagship": 'https://ageofempires.fandom.com//wiki/Lizzie%27s_Flagship',
#  'Buccaneer Captain': 'https://ageofempires.fandom.com//wiki/Barbary_Corsair#Buccaneer_Captain',
#  'Aztec Chief': 'https://ageofempires.fandom.com//wiki/Aztec_Chief',
#  'Dinghy': 'https://ageofempires.fandom.com//wiki/Dinghy',
#  'Native Boy': 'https://ageofempires.fandom.com//wiki/Native_Boy',
#  'Treasure Ship': 'https://ageofempires.fandom.com//wiki/Treasure_Ship',
#  'White Jaguar': 'https://ageofempires.fandom.com//wiki/White_Jaguar',
#  'Boneguard Swordsman': 'https://ageofempires.fandom.com//wiki/Boneguard_Swordsman',
#  'Boneguard Musketeer': 'https://ageofempires.fandom.com//wiki/Boneguard_Musketeer',
#  'Cherokee Archer': 'https://ageofempires.fandom.com//wiki/Cherokee_Archer',
#  'Cherokee Horse Archer': 'https://ageofempires.fandom.com//wiki/Cherokee_Horse_Archer',
#  'Native American Chief': 'https://ageofempires.fandom.com//wiki/Native_American_Chief',
#  'Outlaw Musketeer': 'https://ageofempires.fandom.com//wiki/Musketeer#Outlaw_Musketeer',
#  'White Buffalo': 'https://ageofempires.fandom.com//wiki/White_Buffalo',
#  'Great Plains Chief': 'https://ageofempires.fandom.com//wiki/Great_Plains_Chief',
#  'Greta': 'https://ageofempires.fandom.com//wiki/Greta',
#  'Horse': 'https://ageofempires.fandom.com//wiki/Horse#Age_of_Empires_III',
#  'Miner': 'https://ageofempires.fandom.com//wiki/Miner',
#  'Great Cannon': 'https://ageofempires.fandom.com//wiki/Li%27l_Bombard#Great_Cannon',
#  'Railroad Worker': 'https://ageofempires.fandom.com//wiki/Railroad_Worker',
#  'White Wolf': 'https://ageofempires.fandom.com//wiki/White_Wolf',
#  'Fierce Cougar': 'https://ageofempires.fandom.com//wiki/Cougar#Fierce_Cougar',
#  'Black Powder Wagon': 'https://ageofempires.fandom.com//wiki/Black_Powder_Wagon',
#  'Flat-bottomed Boat': 'https://ageofempires.fandom.com//wiki/Flat-bottomed_Boat'}

# %%
def norm_string(s):
    return s.strip().replace(" ", "_").lower()

# %%
def scrape_unit_data(unit, units_urls) -> list:

    TARGET_GAME = "Age of Empires III"

    try:

        url = units_urls[unit]

        unit_html = fetch_page_content(url)
        unit_soup = bs(unit_html, "html.parser")
        infoboxes = unit_soup.find_all("aside", class_="portable-infobox")

        fragment_id = urlparse(url).fragment

        norm_fragment_id = norm_string(fragment_id) if fragment_id else None
        norm_target_game = norm_string(TARGET_GAME)
        norm_unit = norm_string(unit)

        unit_to_search = (norm_unit if norm_fragment_id == norm_target_game else norm_fragment_id) or norm_unit

        infobox = find_infobox(unit_to_search, infoboxes)

        unit_data = extract_unit_data(infobox)

        return unit_data

    except Exception as e:
        raise Exception(f"Error: {e}")

# %%
unit = "Hot Air Balloon"
scrape_unit_data(unit, units_urls)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 21, in scrape_unit_data(unit, units_urls)
#      19 unit_to_search = (norm_unit if norm_fragment_id == norm_target_game else norm_fragment_id) or norm_unit
# ---> 21 infobox = find_infobox(unit_to_search, infoboxes)
#      23 unit_data = extract_unit_data(infobox)
#
# File c:\Users\Jonathan Diaz\Documentos\Proyects\aoe3de_web_scraper\src\scrap_infobox.py:54, in find_infobox(unit_to_search, infoboxes)
#      52         return infobox
# ---> 54 raise ValueError("Infobox not found")
#
# ValueError: Infobox not found
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 unit = "Hot Air Balloon"
# ----> 2 scrape_unit_data(unit, units_urls)
#
# Cell In[6], line 28, in scrape_unit_data(unit, units_urls)
#      25     return unit_data
#      27 except Exception as e:
# ---> 28     raise Exception(f"Error: {e}")
#
# Exception: Error: Infobox not found

# %%
data = {}
for unit in units_urls.keys():
    try:
        data[unit] = scrape_unit_data(unit, units_urls)
    except Exception as e:
        print(f"Extraction error for unit: {unit} - {e}")
print(f"Extracted data for {len(data)} units")
# Out:
# Extraction error for unit: Carib Blowgun Ambusher - Error: Infobox not found
# Extraction error for unit: Eagle Scout - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Hot Air Balloon - Error: Infobox not found
# Extraction error for unit: Wagner the Pet White Tiger - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['×1.3 vs. Light infantry']'
# Extraction error for unit: Buttercup the Pet Cougar - Error: Infobox not found
# Extraction error for unit: Eclaireur - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Militiaman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Revolutionary - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Settler - Error: Information for label 'Cost' could not be extracted in dict format.
# Present values: '['100']'
# Extraction error for unit: Volunteer - Error: Infobox not found
# Extraction error for unit: Battle Canoe - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Battleship - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Berber Camel Rider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Boyar - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Cheyenne Rider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Haudenosaunee Tomahawk - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Healer - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Mounted Infantry - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Qizilbash - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Royal Dragoon - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand']'
# Extraction error for unit: Tatar Archer - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: War Elephant - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Yoruba Eso Rider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Imam - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Missionary - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Padre - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Priest - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Surgeon - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Papal Lancer - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Bersagliere - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Landwehr - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Nizam Fusilier - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['See Unit stance modifications']'
# Extraction error for unit: Chinaco - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Lancer - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Naginata Rider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Oprichnik - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: War Wagon - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Fire Thrower - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as grenade attack']'
# Extraction error for unit: Gatling Gun - Error: Information for label 'Damage' could not be extracted in dict format.
# Present values: '['30 (6)']'
# Extraction error for unit: Grenadier - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Humbaraci - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Leather Cannon - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as bombard attack']'
# Extraction error for unit: Bosniak - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Comanchero - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Cowboy - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Cuatrero - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Dahomey Amazon - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Elmetto - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Inquisitor - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Jat Lancer - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Mounted Rifleman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Sennar Horseman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Wokou Horseman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Cetan Bow - Error: Infobox not found
# Extraction error for unit: Axe Rider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Kanya Horseman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as siege attack']'
# Extraction error for unit: Bolas Warrior - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Huaraca - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Maceman - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['0.67x vs. Economy and Military units']'
# Extraction error for unit: Priestess - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Tokala Soldier - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Warrior - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extraction error for unit: Warrior Priest - Error: Item type not found for label: 'Healing'
# Extraction error for unit: Mahout Lancer - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Sowar - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Flamethrower - Error: Item type not found for label: 'Banner army'
# Extraction error for unit: Hand Mortar - Error: Item type not found for label: 'Banner army'
# Extraction error for unit: Daimyo Kiyomasa - Error: Infobox not found
# Extraction error for unit: Shogun Tokugawa - Error: Infobox not found
# Extraction error for unit: Mansabdar Mahout - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Mansabdar Sowar - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Raider - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as hand attack']'
# Extraction error for unit: Covered Wagon - Error: Infobox not found
# Extraction error for unit: Morgan's Flagship - Error: Infobox not found
# Extraction error for unit: Lizzie's Flagship - Error: Infobox not found
# Extraction error for unit: Boneguard Swordsman - Error: Infobox not found
# Extraction error for unit: Boneguard Musketeer - Error: Infobox not found
# Extraction error for unit: Greta - Error: Information for label 'Bonus damage' could not be extracted in dict format.
# Present values: '['Same as ranged attack']'
# Extracted data for 307 units

# %% [markdown]
# ## Scraped Wiki Data Analysis

# %%
unit = "Eagle Scout"
unit_url = units_urls[unit]
print("unit_url: ", unit_url)
print()

parsed_url = urlparse(unit_url)

print("scheme: ", parsed_url.scheme)
print("netloc: ", parsed_url.netloc)
print("path: ", parsed_url.path)
print("query: ", parsed_url.query)
print("fragment: ", parsed_url.fragment)
print()

unit_html = fetch_page_content(unit_url)
unit_soup = bs(unit_html, "html.parser")
infoboxes = unit_soup.find_all("aside", class_="portable-infobox")
print("infoboxes: ", len(infoboxes))
# Out:
# unit_url:  https://ageofempires.fandom.com//wiki/Eagle_Scout_(Age_of_Empires_III)
#
# scheme:  https
# netloc:  ageofempires.fandom.com
# path:  //wiki/Eagle_Scout_(Age_of_Empires_III)
# query:
# fragment:
#
# infoboxes:  1

# %%
unit_html = fetch_page_content(unit_url)
unit_soup = bs(unit_html, "html.parser")
infoboxes = unit_soup.find_all("aside", class_="portable-infobox")
fragment_id = urlparse(unit_url).fragment

# %%
TARGET_GAME = "Age of Empires III"

def norm_string(s):
    return s.strip().replace(" ", "_").lower()

norm_fragment_id = norm_string(fragment_id) if fragment_id else None
norm_target_game = norm_string(TARGET_GAME)
norm_unit = norm_string(unit)

unit_to_search = (norm_unit if norm_fragment_id == norm_target_game else norm_fragment_id) or norm_unit
unit_to_search
# Out:
# 'eagle_scout'

# %%
for infobox in infoboxes:

    # Title verification
    game_div = infobox.find("div", class_="pi-data-value")

    if not game_div:
        continue

    game = game_div.text.strip()

    if TARGET_GAME not in game:
        founded = False
        print("Game doesn't match")
        print("TARGET_GAME: ", TARGET_GAME)
        print("game: ", game)
        print()
        continue

    # Unit name verification
    unit_name = infobox.find("h2")
    if not unit_name:
        continue

    norm_infobox = unit_name.text.strip().replace(" ", "_").lower()

    if not unit_to_search == norm_infobox:

        founded = False
        print("Unit name doesn't match")
        print("unit_to_search: ", unit_to_search)
        print("infobox_name: ", norm_infobox)
        print()
        continue

    else:
        founded = True
        print("Unit name matches")
        print("unit_to_search: ", unit_to_search)
        print("infobox_name: ", norm_infobox)
        print()
        break

if founded:
    print("Game matches")
    print("TARGET_GAME: ", TARGET_GAME)
    print("game: ", game)
    print("Infobox found")
else:
    print("Infobox not found")
# Out:
# Unit name matches
# unit_to_search:  eagle_scout
# infobox_name:  eagle_scout
#
# Game matches
# TARGET_GAME:  Age of Empires III
# game:  Age of Empires III: Definitive Edition
# Infobox found
